# %% [raw]
# Project on Heart_Disease_Prediction

# %%
import pandas as pd

# %%
df=pd.read_csv("dataset1.csv")

# %%
df.head()
# Out:
#    Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0   70    1                4  130          322             0            2
# 1   67    0                3  115          564             0            2
# 2   57    1                2  124          261             0            0
# 3   64    1                4  128          263             0            0
# 4   74    0                2  120          269             0            2
#
#    Max HR  Exercise angina  ST depression  Slope of ST  \
# 0     109                0            2.4            2
# 1     160                0            1.6            2
# 2     141                0            0.3            1
# 3     105                1            0.2            2
# 4     121                1            0.2            1
#
#    Number of vessels fluro  Thallium Heart Disease
# 0                        3         3      Presence
# 1                        0         7       Absence
# 2                        0         7      Presence
# 3                        1         7       Absence
# 4                        1         3       Absence

# %%
x=df[["Age","Sex","Chest pain type","BP","Cholesterol","FBS over 120","EKG results","Max HR","Exercise angina","ST depression","Slope of ST","Number of vessels fluro","Thallium"]]

# %%
x
# Out:
#      Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0     70    1                4  130          322             0            2
# 1     67    0                3  115          564             0            2
# 2     57    1                2  124          261             0            0
# 3     64    1                4  128          263             0            0
# 4     74    0                2  120          269             0            2
# ..   ...  ...              ...  ...          ...           ...          ...
# 265   52    1                3  172          199             1            0
# 266   44    1                2  120          263             0            0
# 267   56    0                2  140          294             0            2
# 268   57    1                4  140          192             0            0
# 269   67    1                4  160          286             0            2
#
#      Max HR  Exercise angina  ST depression  Slope of ST  \
# 0       109                0            2.4            2
# 1       160                0            1.6            2
# 2       141                0            0.3            1
# 3       105                1            0.2            2
# 4       121                1            0.2            1
# ..      ...              ...            ...          ...
# 265     162                0            0.5            1
# 266     173                0            0.0            1
# 267     153                0            1.3            2
# 268     148                0            0.4            2
# 269     108                1            1.5            2
#
#      Number of vessels fluro  Thallium
# 0                          3         3
# 1                          0         7
# 2                          0         7
# 3                          1         7
# 4                          1         3
# ..                       ...       ...
# 265                        0         7
# 266                        0         7
# 267                        0         3
# 268                        0         6
# 269                        3         3
#
# [270 rows x 13 columns]

# %%
y=df[["Heart Disease"]]

# %%
y
# Out:
#     Heart Disease
# 0        Presence
# 1         Absence
# 2        Presence
# 3         Absence
# 4         Absence
# ..            ...
# 265       Absence
# 266       Absence
# 267       Absence
# 268       Absence
# 269      Presence
#
# [270 rows x 1 columns]

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
Y=pd.get_dummies(y)

# %%
Y
# Out:
#      Heart Disease_Absence  Heart Disease_Presence
# 0                    False                    True
# 1                     True                   False
# 2                    False                    True
# 3                     True                   False
# 4                     True                   False
# ..                     ...                     ...
# 265                   True                   False
# 266                   True                   False
# 267                   True                   False
# 268                   True                   False
# 269                  False                    True
#
# [270 rows x 2 columns]

# %%
model.fit(x,Y)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([[ 0.00186447, -0.15943693, -0.09386549, -0.00204968, -0.00060281,
#          0.08097326, -0.03941269,  0.00272135, -0.11522742, -0.04366018,
#         -0.04761571, -0.13516679, -0.05946612],
#        [-0.00186447,  0.15943693,  0.09386549,  0.00204968,  0.00060281,
#         -0.08097326,  0.03941269, -0.00272135,  0.11522742,  0.04366018,
#          0.04761571,  0.13516679,  0.05946612]])

# %%
model.intercept_
# Out:
# array([ 1.42992985, -0.42992985])

# %%
df
# Out:
#      Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0     70    1                4  130          322             0            2
# 1     67    0                3  115          564             0            2
# 2     57    1                2  124          261             0            0
# 3     64    1                4  128          263             0            0
# 4     74    0                2  120          269             0            2
# ..   ...  ...              ...  ...          ...           ...          ...
# 265   52    1                3  172          199             1            0
# 266   44    1                2  120          263             0            0
# 267   56    0                2  140          294             0            2
# 268   57    1                4  140          192             0            0
# 269   67    1                4  160          286             0            2
#
#      Max HR  Exercise angina  ST depression  Slope of ST  \
# 0       109                0            2.4            2
# 1       160                0            1.6            2
# 2       141                0            0.3            1
# 3       105                1            0.2            2
# 4       121                1            0.2            1
# ..      ...              ...            ...          ...
# 265     162                0            0.5            1
# 266     173                0            0.0            1
# 267     153                0            1.3            2
# 268     148                0            0.4            2
# 269     108                1            1.5            2
#
#      Number of vessels fluro  Thallium Heart Disease
# 0                          3         3      Presence
# 1                          0         7       Absence
# 2                          0         7      Presence
# 3                          1         7       Absence
# 4                          1         3       Absence
# ..                       ...       ...           ...
# 265                        0         7       Absence
# 266                        0         7       Absence
# 267                        0         3       Absence
# 268                        0         6       Absence
# 269                        3         3      Presence
#
# [270 rows x 14 columns]

# %%
from sklearn.tree import DecisionTreeClassifier
import warnings
warnings.filterwarnings("ignore")
model.predict([[50,1,3,100,235,1,2,157,0,28,2,1,6]])
# Out:
# array([[-0.6447877,  1.6447877]])
